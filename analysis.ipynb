# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
con = create_engine('sqlite:///one.sqlite')

# %%
query = "SELECT * FROM orders"
df_orders = pd.read_sql(query,con)
df_expenses = pd.read_sql("SELECT * FROM expenses", con)
# Out:
# Engine(sqlite:///one.sqlite)

# %%
df_orders
# Out:
#     id  ord_num  ord_amount  advance_amount    ord_date cust_code agent_code  \
# 0    1   200100      1000.0           600.0  08/01/2008    C00013       A003
# 1    2   200110      3000.0           500.0  04/15/2008    C00019       A010
# 2    3   200107      4500.0           900.0  08/30/2008    C00007       A010
# 3    4   200112      2000.0           400.0  05/30/2008    C00016       A007
# 4    5   200113      4000.0           600.0  06/10/2008    C00022       A002
# 5    6   200102      2000.0           300.0  05/25/2008    C00012       A012
# 6    7   200114      3500.0          2000.0  08/15/2008    C00002       A008
# 7    8   200122      2500.0           400.0  09/16/2008    C00003       A004
# 8    9   200118       500.0           100.0  07/20/2008    C00023       A006
# 9   10   200119      4000.0           700.0  09/16/2008    C00007       A010
# 10  11   200121      1500.0           600.0  09/23/2008    C00008       A004
# 11  12   200130      2500.0           400.0  07/30/2008    C00025       A011
# 12  13   200134      4200.0          1800.0  09/25/2008    C00004       A005
# 13  14   200108      4000.0           600.0  02/15/2008    C00008       A004
# 14  15   200103      1500.0           700.0  05/15/2008    C00021       A005
# 15  16   200105      2500.0           500.0  07/18/2008    C00025       A011
# 16  17   200109      3500.0           800.0  07/30/2008    C00011       A010
# 17  18   200101      3000.0          1000.0  07/15/2008    C00001       A008
# 18  19   200111      1000.0           300.0  07/10/2008    C00020       A008
# 19  20   200104      1500.0           500.0  03/13/2008    C00006       A004
# 20  21   200106      2500.0           700.0  04/20/2008    C00005       A002
# 21  22   200125      2000.0           600.0  10/10/2008    C00018       A005
# 22  23   200117       800.0           200.0  10/20/2008    C00014       A001
# 23  24   200123       500.0           100.0  09/16/2008    C00022       A002
# 24  25   200120       500.0           100.0  07/20/2008    C00009       A002
# 25  26   200116       500.0           100.0  07/13/2008    C00010       A009
# 26  27   200124       500.0           100.0  06/20/2008    C00017       A007
# 27  28   200126       500.0           100.0  06/24/2008    C00022       A002
# 28  29   200129      2500.0           500.0  07/20/2008    C00024       A006
# 29  30   200127      2500.0           400.0  07/20/2008    C00015       A003
# 30  31   200128      3500.0          1500.0  07/20/2008    C00009       A002
# 31  32   200135      2000.0           800.0  09/16/2008    C00007       A010
# 32  33   200131       900.0           150.0  08/26/2008    C00012       A012
# 33  34   200133      1200.0           400.0  06/29/2008    C00009       A002
#
#    ord_description
# 0              SOD
# 1              SOD
# 2              SOD
# 3              SOD
# 4              SOD
# 5              SOD
# 6              SOD
# 7              SOD
# 8              SOD
# 9              SOD
# 10             SOD
# 11             SOD
# 12             SOD
# 13             SOD
# 14             SOD
# 15             SOD
# 16             SOD
# 17             SOD
# 18             SOD
# 19             SOD
# 20             SOD
# 21             SOD
# 22             SOD
# 23             SOD
# 24             SOD
# 25             SOD
# 26             SOD
# 27             SOD
# 28             SOD
# 29             SOD
# 30             SOD
# 31             SOD
# 32             SOD
# 33             SOD
